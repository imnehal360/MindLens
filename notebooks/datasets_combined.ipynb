# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/muhammadnehal/Desktop/mindlens/datasets/text/depression_dataset_reddit_cleaned.csv')

# %%
df1.head()
# Out:
#                                           clean_text  is_depression
# 0  we understand that most people who reply immed...              1
# 1  welcome to r depression s check in post a plac...              1
# 2  anyone else instead of sleeping more when depr...              1
# 3  i ve kind of stuffed around a lot in my life d...              1
# 4  sleep is my greatest and most comforting escap...              1

# %%
df1.shape
# Out:
# (7731, 2)

# %%
df1.tail()
# Out:
#                                              clean_text  is_depression
# 7726                                       is that snow              0
# 7727                 moulin rouge mad me cry once again              0
# 7728  trying to shout but can t find people on the list              0
# 7729  ughh can t find my red sox hat got ta wear thi...              0
# 7730  slept wonderfully finally tried swatching for ...              0

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7731 entries, 0 to 7730
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clean_text     7731 non-null   str
#  1   is_depression  7731 non-null   int64
# dtypes: int64(1), str(1)
# memory usage: 120.9 KB

# %%
df1.isnull().sum()
# Out:
# clean_text       0
# is_depression    0
# dtype: int64

# %%
df2 = pd.read_csv('/Users/muhammadnehal/Desktop/mindlens/datasets/text/Suicide_Detection.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0                                               text        class
# 0           2  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1           3  Am I weird I don't get affected by compliments...  non-suicide
# 2           4  Finally 2020 is almost over... So I can never ...  non-suicide
# 3           8          i need helpjust help me im crying so hard      suicide
# 4           9  I’m so lostHello, my name is Adam (16) and I’v...      suicide

# %%
df2.shape
# Out:
# (232074, 3)

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['clean_text', 'is_depression'], dtype='str')
# Index(['Unnamed: 0', 'text', 'class'], dtype='str')

# %%
df2.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df2.head()
# Out:
#                                                 text        class
# 0  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1  Am I weird I don't get affected by compliments...  non-suicide
# 2  Finally 2020 is almost over... So I can never ...  non-suicide
# 3          i need helpjust help me im crying so hard      suicide
# 4  I’m so lostHello, my name is Adam (16) and I’v...      suicide

# %%
print(df2.columns)
# Out:
# Index(['text', 'class'], dtype='str')

# %%
df1 = df1.rename(columns={"clean_text":"text"})
df1 = df1.rename(columns={"is_depression":"target"})
df2 = df2.rename(columns={"class":"target"})

# %%
df1.head()
# Out:
#                                                 text  target
# 0  we understand that most people who reply immed...       1
# 1  welcome to r depression s check in post a plac...       1
# 2  anyone else instead of sleeping more when depr...       1
# 3  i ve kind of stuffed around a lot in my life d...       1
# 4  sleep is my greatest and most comforting escap...       1

# %%
df2.head()
# Out:
#                                                 text       target
# 0  Ex Wife Threatening SuicideRecently I left my ...      suicide
# 1  Am I weird I don't get affected by compliments...  non-suicide
# 2  Finally 2020 is almost over... So I can never ...  non-suicide
# 3          i need helpjust help me im crying so hard      suicide
# 4  I’m so lostHello, my name is Adam (16) and I’v...      suicide

# %%
df2["target"] = df2["target"].map({
    "suicide":1,
    "non-suicide":0
})

# %%
df2.head()
# Out:
#                                                 text  target
# 0  Ex Wife Threatening SuicideRecently I left my ...       1
# 1  Am I weird I don't get affected by compliments...       0
# 2  Finally 2020 is almost over... So I can never ...       0
# 3          i need helpjust help me im crying so hard       1
# 4  I’m so lostHello, my name is Adam (16) and I’v...       1

# %%
combined_df = pd.concat([df1, df2], ignore_index=True)

# %%
combined_df = combined_df.sample(frac=1).reset_index(drop=True)

# %%
combined_df.head()
# Out:
#                                                 text  target
# 0  I'm almost at a breaking point...New Year's Ev...       1
# 1  There’s no joy leftI spent too much of my life...       1
# 2  I often cut myself. But of sanity not sadnessI...       1
# 3  Please just someone talk to meI'm crying and o...       1
# 4  Little do my friends know that they are the on...       0

# %%
combined_df.shape
# Out:
# (239805, 2)

# %%
combined_df.to_csv("mindlens_text_dataset.csv", index=False)
